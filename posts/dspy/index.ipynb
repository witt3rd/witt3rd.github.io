# %% [raw]
# ---
# title: DSPy Tutorial
# author: Donald Thompson
# date: "May 7, 2024"
# categories: [code, tutorial]
# format:
#   html:
#     code-fold: true
# ---

# %% [markdown]
# # DSPy Tutorial
#
# For a demonstration of the DSPy package, we will use the following @fig-dspy.

# %%
#| label: fig-dspy
#| fig-cap: Displaying Plots

import numpy as np
import matplotlib.pyplot as plt

# Generate some random data
theta = np.linspace(0, 2*np.pi, 100)
r = np.random.rand(100)

# Create a polar plot
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r)

# Set the title and show the plot
ax.set_title('Line Plot on Polar Axis')
plt.show()
